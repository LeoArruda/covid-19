# %% [markdown]
# # Covid 19 - Dataset Processing

# %% [markdown]
# by: Leandro Arruda
# Special thanks for Mario Filho https://github.com/ledmaster

# %% [markdown]
# ## Exploring Distance between Countries and  Confirmed cases

# %% [markdown]
# [https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_population_density]
#
# [https://www.kaggle.com/sudalairajkumar/novel-corona-virus-2019-dataset]
#
# [https://www.kaggle.com/fernandol/countries-of-the-world]
#
# [https://www.kaggle.com/max-mind/world-cities-database]
#
# [https://www.kaggle.com/andradaolteanu/iso-country-codes-global]
#
# [https://www.kaggle.com/folaraz/world-countries-and-continents-details]

# %% [markdown]
# I explored several datasets, looking for certain characteristics that might influences CoVid-19 prediction.
# In result, I ended up with the idea to look at:
#     * The proximity of countries
#     * Countries which had SARS. (Since there're some common characteristics. I.e. Both are a Coronavirus infection, the initial cases started in the same countries, among others)
#     * Population density. (Observing the spread characteristic)

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from datetime import datetime
from geopy.distance import geodesic
import os
#plt.figure(figsize=(16,6))

# %% [markdown]
# ## Reading the datasets

# %%
# Input data files are available in the "../data/" directory.

for dirname, _, filenames in os.walk('.\data'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# .\data\2019_nCoV_data.csv
# .\data\countries-lat-lon.csv
# .\data\countries.csv
# .\data\countries_and_continents.csv
# .\data\covid_19_data.csv
# .\data\covid_19_processed.csv
# .\data\Population.csv
# .\data\sars.csv
# .\data\time_series_covid_19_confirmed.csv
# .\data\time_series_covid_19_deaths.csv
# .\data\time_series_covid_19_recovered.csv

# %%
covid = pd.read_csv('./data/covid_19_data.csv')
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
countries = pd.read_csv("./data/countries.csv")
countries_loc = pd.read_csv("./data/countries-lat-lon.csv", index_col=0)
countries.head()
# Out:
#           name official_name_en      official_name_fr ISO3166-1-Alpha-2  \
# 0          NaN  Channel Islands  Îles Anglo-Normandes               NaN
# 1          NaN             Sark                 Sercq               NaN
# 2  Afghanistan      Afghanistan           Afghanistan                AF
# 3      Albania          Albania               Albanie                AL
# 4      Algeria          Algeria               Algérie                DZ
#
#   ISO3166-1-Alpha-3  M49  ITU MARC  WMO   DS  ...    \
# 0               NaN  830  NaN  NaN  NaN  NaN  ...
# 1               NaN  680  NaN  NaN  NaN  NaN  ...
# 2               AFG    4  AFG   af   AF  AFG  ...
# 3               ALB    8  ALB   aa   AB   AL  ...
# 4               DZA   12  ALG   ae   AL   DZ  ...
#
#   ISO4217-currency_minor_unit ISO4217-currency_name  \
# 0                         NaN                   NaN
# 1                         NaN                   NaN
# 2                         2.0               Afghani
# 3                         2.0                   Lek
# 4                         2.0        Algerian Dinar
#
#   ISO4217-currency_numeric_code is_independent  Capital Continent  TLD  \
# 0                           NaN            NaN      NaN       NaN  NaN
# 1                           NaN            NaN      NaN       NaN  NaN
# 2                         971.0            Yes    Kabul        AS  .af
# 3                           8.0            Yes   Tirana        EU  .al
# 4                          12.0            Yes  Algiers        AF  .dz
#
#            Languages Geoname ID  EDGAR
# 0                NaN        NaN    NaN
# 1                NaN        NaN    NaN
# 2  fa-AF,ps,uz-AF,tk  1149361.0     B2
# 3              sq,el   783754.0     B3
# 4              ar-DZ  2589581.0     B4
#
# [5 rows x 27 columns]

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### Preparing COVID dataset merging other datasets

# %%
covid['ObservationDate'] = pd.to_datetime(covid['ObservationDate'], format='%m/%d/%Y')
covid.loc[covid['Country/Region'] == 'China', 'Country/Region'] = 'Mainland China'
covid.loc[covid['Country/Region'] == 'North Ireland', 'Country/Region'] = 'Ireland'
covid.loc[covid['Country/Region'] == 'North Macedonia', 'Country/Region'] = 'Macedonia'
covid.loc[covid['Country/Region'] == ' Azerbaijan', 'Country/Region'] = 'Azerbaijan' 
covid.loc[covid['Country/Region'] == 'Côte d’Ivoire', 'Country/Region'] = 'Ivory Coast'

# %%
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1    2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2    3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4    5      2020-01-22          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
covid = covid[covid['Confirmed'] > 0]

# %%
covid['Country/Region'].value_counts().head(10)
# Out:
# Mainland China    1160
# US                 340
# Australia          134
# Canada              92
# Macau               38
# South Korea         38
# Japan               38
# Taiwan              38
# Thailand            38
# Vietnam             37
# Name: Country/Region, dtype: int64

# %%
#covid = covid.drop_duplicates("Country/Region")
covid = covid[covid["Country/Region"] != "Others"]
covid = covid.reset_index(drop=True)
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1    2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2    3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4    6      2020-01-22      Guangdong  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4       26.0     0.0        0.0

# %% [markdown]
# ### Preparing World Countries & Location to Merge into COVID dataset

# %% [markdown]
# **Renaming Name column**

# %%
countries_loc = countries_loc.rename(columns={"name": "Country/Region"})
countries_loc = countries_loc.dropna()
countries_loc.head()
# Out:
#    longitude    latitude  Country/Region
# 2  33.939110   67.709953     Afghanistan
# 3  41.153332   20.168331         Albania
# 4  28.033886    1.659626         Algeria
# 5 -14.270972 -170.132217  American Samoa
# 6  42.506285    1.521801         Andorra

# %%
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1    2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2    3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4    6      2020-01-22      Guangdong  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4       26.0     0.0        0.0

# %%
countries_loc.loc[countries_loc['Country/Region'] == 'China', 'Country/Region'] = 'Mainland China'
countries_loc.loc[countries_loc['Country/Region'] == 'Côte d’Ivoire', 'Country/Region'] = 'Ivory Coast'

# %% [markdown]
# ### Preparing SARS Dataset to Merge into COVID dataset

# %%
sars = pd.read_csv('./data/sars.csv')
sars['Country or region'] = sars['Country or region'].str.strip()
sars.loc[sars['Country or region'] == 'China', 'Country or region'] = 'Mainland China'
sars.loc[sars['Country or region'] == 'United States', 'Country or region'] = 'US'
sars.loc[sars['Country or region'] == 'United Kingdom', 'Country or region'] = 'UK'
sars['SARS'] = 1
sars = sars.rename(columns={'Country or region': "Country/Region"})
sars = sars.rename(columns={'Cases': "SARS_Cases"})
sars = sars.rename(columns={'Deaths': "SARS_Deaths"})
sars = sars.rename(columns={'Fatality (%)': "SARS_Fatality"})
sars.head()
# Out:
#    Country/Region  SARS_Cases  SARS_Deaths  SARS_Fatality  SARS
# 0  Mainland China        5327          349            6.6     1
# 1       Hong Kong        1755          299           17.0     1
# 2          Taiwan         346           73           21.1     1
# 3          Canada         251           43           17.1     1
# 4       Singapore         238           33           13.9     1

# %%
countries_loc = countries_loc.merge(sars, how='left', on='Country/Region')

# %%
countries_loc.loc[countries_loc['Country/Region']=='Mainland China']
# Out:
#     longitude    latitude  Country/Region  SARS_Cases  SARS_Deaths  \
# 45   35.86166  104.195397  Mainland China      5327.0        349.0
#
#     SARS_Fatality  SARS
# 45            6.6   1.0

# %%
covid = covid.merge(countries_loc, how='left', on='Country/Region')

# %%
covid.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      2020-01-22          Anhui  Mainland China  1/22/2020 17:00
# 1    2      2020-01-22        Beijing  Mainland China  1/22/2020 17:00
# 2    3      2020-01-22      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      2020-01-22         Fujian  Mainland China  1/22/2020 17:00
# 4    6      2020-01-22      Guangdong  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered  longitude    latitude  SARS_Cases  \
# 0        1.0     0.0        0.0   35.86166  104.195397      5327.0
# 1       14.0     0.0        0.0   35.86166  104.195397      5327.0
# 2        6.0     0.0        0.0   35.86166  104.195397      5327.0
# 3        1.0     0.0        0.0   35.86166  104.195397      5327.0
# 4       26.0     0.0        0.0   35.86166  104.195397      5327.0
#
#    SARS_Deaths  SARS_Fatality  SARS
# 0        349.0            6.6   1.0
# 1        349.0            6.6   1.0
# 2        349.0            6.6   1.0
# 3        349.0            6.6   1.0
# 4        349.0            6.6   1.0

# %% [markdown]
# ### Preparing Population Dataset to Merge into COVID dataset

# %%
population = pd.read_csv('./data/population.csv')
population.head()
# Out:
#             Country  Population  Land Area  Population Density  \
# 0         Singapore     5612253      682.7              7916.0
# 1  Hong Kong S.A.R.     7391700     1042.0              7040.0
# 2           Bahrain     1492584      665.0              1936.0
# 3        Seychelles       95843      455.0               208.0
# 4            Kuwait     4136528    17820.0               232.0
#
#   % of land arable Arable Land  Real Population Density 2016
# 0            0.79%         560                         0.000
# 1            2.86%        3000                         0.000
# 2            2.06%        1600                         0.001
# 3            0.33%         150                         0.002
# 4            0.45%        8000                         0.002

# %%
population.loc[population['Country'] == 'China', 'Country'] = 'Mainland China'
population.loc[population['Country'] == 'United States', 'Country'] = 'US'
population.loc[population['Country'] == 'United Kingdom', 'Country'] = 'UK'

# %%
population = population.rename(columns={"Country": "Country/Region"})

# %%
population = population.drop(columns=['Land Area', '% of land arable','Arable Land','Real Population Density 2016'])

# %%
population.head()
# Out:
#      Country/Region  Population  Population Density
# 0         Singapore     5612253              7916.0
# 1  Hong Kong S.A.R.     7391700              7040.0
# 2           Bahrain     1492584              1936.0
# 3        Seychelles       95843               208.0
# 4            Kuwait     4136528               232.0

# %%
covid = covid.merge(population, how='left', on='Country/Region')

# %%
covid['SARS_Cases'] = covid['SARS_Cases'].astype(float).fillna(0)
covid['SARS'] = covid['SARS'].astype(float).fillna(0)

# 2614  -51.925280         0.0          NaN            NaN   0.0  2.092883e+08
# 2615  104.990963         0.0          NaN            NaN   0.0  1.600537e+07
# 2616 -106.346771       251.0         43.0           17.1   1.0  3.670808e+07
# 2617 -106.346771       251.0         43.0           17.1   1.0  3.670808e+07
# 2618    9.501785         0.0          NaN            NaN   0.0  5.769603e+06
# 2619   30.802498         0.0          NaN            NaN   0.0  9.755315e+07
# 2620   25.013607         0.0          NaN            NaN   0.0  1.315480e+06
# 2621  -82.900075         0.0          NaN            NaN   0.0  3.717100e+06
# 2622  -19.020835         0.0          NaN            NaN   0.0  3.412840e+05
# 2623   23.881275         0.0          NaN            NaN   0.0  2.827721e+06
# 2624  104.195397      5327.0        349.0            6.6   1.0  1.386395e+09
# 2625 -102.552784         0.0          NaN            NaN   0.0  1.291633e+08
# 2626   84.124008         0.0          NaN            NaN   0.0  2.930500e+07
# 2627    5.291266         0.0          NaN            NaN   0.0  1.713285e+07
# 2628  174.885971         1.0          0.0            0.0   1.0  4.793900e+06
# 2629    8.675277         0.0          NaN            NaN   0.0  1.908863e+08
# 2630   -7.692054         1.0          0.0            0.0   1.0  4.813608e+06
# 2631   21.745275         0.0          NaN            NaN   0.0  2.083160e+06
# 2632   12.457777         0.0          NaN            NaN   0.0  3.340000e+04
# 2633   80.771797         0.0          NaN            NaN   0.0  2.144400e+07
# 2634  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2635  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2636  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2637  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2638  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2639  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2640  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
# 2641  -73.978890        27.0          0.0            0.0   1.0  3.257192e+08
#
#       Population Density
# 0                  148.0
# 1                  148.0
# 2                  148.0
# 3                  148.0
# 4                  148.0
# 5                  148.0
# 6                  148.0
# 7                  148.0
# 8                  148.0
# 9                  148.0
# 10                 148.0
# 11                 148.0
# 12                 148.0
# 13                 148.0
# 14                 148.0
# 15                   NaN
# 16                 148.0
# 17                 148.0
# 18                 148.0
# 19                 148.0
# 20                 148.0
# 21                 704.0
# 22                 148.0
# 23                  36.0
# 24                 148.0
# 25                 148.0
# 26                 348.0
# 27                 135.0
# 28                 528.0
# 29                 148.0
# ...                  ...
# 2612                47.0
# 2613               376.0
# 2614                25.0
# 2615                91.0
# 2616                 4.0
# 2617                 4.0
# 2618               137.0
# 2619                98.0
# 2620                31.0
# 2621                65.0
# 2622                 3.0
# 2623                45.0
# 2624               148.0
# 2625                66.0
# 2626               204.0
# 2627               509.0
# 2628                18.0
# 2629               210.0
# 2630                70.0
# 2631                83.0
# 2632               557.0
# 2633               342.0
# 2634                36.0
# 2635                36.0
# 2636                36.0
# 2637                36.0
# 2638                36.0
# 2639                36.0
# 2640                36.0
# 2641                36.0
#
# [2642 rows x 16 columns]

# %% [markdown]
# ### Saving the new CoViD-19 dataset

# %%
covid.to_csv('./data/covid_19_processed.csv')
